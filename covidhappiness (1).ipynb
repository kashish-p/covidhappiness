# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

print('Modules are imported.')
# Out:
# Modules are imported.

# %%
corona_dataset_csv = pd.read_csv('Datasets/covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  Unnamed: 290  \
# 0        0        0        0        0        0        0  ...           NaN
# 1        0        0        0        0        0        0  ...           NaN
# 2        0        0        0        0        0        0  ...           NaN
# 3        0        0        0        0        0        0  ...           NaN
# 4        0        0        0        0        0        0  ...           NaN
# 5        0        0        0        0        0        0  ...           NaN
# 6        0        0        0        0        0        0  ...           NaN
# 7        0        0        0        0        0        0  ...           NaN
# 8        0        0        0        0        0        0  ...           NaN
# 9        0        0        0        0        3        4  ...           NaN
#
#    Unnamed: 291  Unnamed: 292  Unnamed: 293  Unnamed: 294  Unnamed: 295  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 296  Unnamed: 297  Unnamed: 298  Unnamed: 299
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN
#
# [10 rows x 300 columns]

# %%
corona_dataset_csv.shape
# Out:
# (271, 300)

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-cf15cef5db20> in <module>
# ----> 1 corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['Lat' 'Long'] not found in axis"

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  Unnamed: 290  \
# 0        0        0        0        0        0        0  ...           NaN
# 1        0        0        0        0        0        0  ...           NaN
# 2        0        0        0        0        0        0  ...           NaN
# 3        0        0        0        0        0        0  ...           NaN
# 4        0        0        0        0        0        0  ...           NaN
# 5        0        0        0        0        0        0  ...           NaN
# 6        0        0        0        0        0        0  ...           NaN
# 7        0        0        0        0        0        0  ...           NaN
# 8        0        0        0        0        0        0  ...           NaN
# 9        0        0        3        4        4        4  ...           NaN
#
#    Unnamed: 291  Unnamed: 292  Unnamed: 293  Unnamed: 294  Unnamed: 295  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 296  Unnamed: 297  Unnamed: 298  Unnamed: 299
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN
#
# [10 rows x 298 columns]

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  Unnamed: 290  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...           0.0
# Albania                    0        0        0        0  ...           0.0
# Algeria                    0        0        0        0  ...           0.0
# Andorra                    0        0        0        0  ...           0.0
# Angola                     0        0        0        0  ...           0.0
# Antigua and Barbuda        0        0        0        0  ...           0.0
# Argentina                  0        0        0        0  ...           0.0
# Armenia                    0        0        0        0  ...           0.0
# Australia                  5        6        9        9  ...           0.0
# Austria                    0        0        0        0  ...           0.0
#
#                      Unnamed: 291  Unnamed: 292  Unnamed: 293  Unnamed: 294  \
# Country/Region
# Afghanistan                   0.0           0.0           0.0           0.0
# Albania                       0.0           0.0           0.0           0.0
# Algeria                       0.0           0.0           0.0           0.0
# Andorra                       0.0           0.0           0.0           0.0
# Angola                        0.0           0.0           0.0           0.0
# Antigua and Barbuda           0.0           0.0           0.0           0.0
# Argentina                     0.0           0.0           0.0           0.0
# Armenia                       0.0           0.0           0.0           0.0
# Australia                     0.0           0.0           0.0           0.0
# Austria                       0.0           0.0           0.0           0.0
#
#                      Unnamed: 295  Unnamed: 296  Unnamed: 297  Unnamed: 298  \
# Country/Region
# Afghanistan                   0.0           0.0           0.0           0.0
# Albania                       0.0           0.0           0.0           0.0
# Algeria                       0.0           0.0           0.0           0.0
# Andorra                       0.0           0.0           0.0           0.0
# Angola                        0.0           0.0           0.0           0.0
# Antigua and Barbuda           0.0           0.0           0.0           0.0
# Argentina                     0.0           0.0           0.0           0.0
# Armenia                       0.0           0.0           0.0           0.0
# Australia                     0.0           0.0           0.0           0.0
# Austria                       0.0           0.0           0.0           0.0
#
#                      Unnamed: 299
# Country/Region
# Afghanistan                   0.0
# Albania                       0.0
# Algeria                       0.0
# Andorra                       0.0
# Angola                        0.0
# Antigua and Barbuda           0.0
# Argentina                     0.0
# Armenia                       0.0
# Australia                     0.0
# Austria                       0.0
#
# [10 rows x 296 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (191, 296)

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  Unnamed: 291  Unnamed: 292  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...           0.0           0.0
# Albania               0        0        0  ...           0.0           0.0
# Algeria               0        0        0  ...           0.0           0.0
# Andorra               0        0        0  ...           0.0           0.0
# Angola                0        0        0  ...           0.0           0.0
#
#                 Unnamed: 293  Unnamed: 294  Unnamed: 295  Unnamed: 296  \
# Country/Region
# Afghanistan              0.0           0.0           0.0           0.0
# Albania                  0.0           0.0           0.0           0.0
# Algeria                  0.0           0.0           0.0           0.0
# Andorra                  0.0           0.0           0.0           0.0
# Angola                   0.0           0.0           0.0           0.0
#
#                 Unnamed: 297  Unnamed: 298  Unnamed: 299  max infection rate
# Country/Region
# Afghanistan              0.0           0.0           0.0               232.0
# Albania                  0.0           0.0           0.0                34.0
# Algeria                  0.0           0.0           0.0               199.0
# Andorra                  0.0           0.0           0.0                43.0
# Angola                   0.0           0.0           0.0                 5.0
#
# [5 rows x 297 columns]

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
world_happiness_report = pd.read_csv("Datasets/2020_report.csv")
world_happiness_report.head()
# Out:
#        country  happiness_score  gdp_per_capita  social_support    health  \
# 0      Finland           7.8087        1.285190        1.499526  0.961271
# 1      Denmark           7.6456        1.326949        1.503449  0.979333
# 2  Switzerland           7.5599        1.390774        1.472403  1.040533
# 3      Iceland           7.5045        1.326502        1.547567  1.000843
# 4       Norway           7.4880        1.424207        1.495173  1.008072
#
#     freedom  generosity  government_trust  dystopia_residual continent
# 0  0.662317    0.159670          0.477857           2.762835    Europe
# 1  0.665040    0.242793          0.495260           2.432741    Europe
# 2  0.628954    0.269056          0.407946           2.350267    Europe
# 3  0.661981    0.362330          0.144541           2.460688    Europe
# 4  0.670201    0.287985          0.434101           2.168266    Europe

# %%
world_happiness_report.shape
# Out:
# (138, 10)

# %%
columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e2e7b73a1126> in <module>
#       1 columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']
# ----> 2 world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['Overall rank' 'Score' 'Generosity' 'Perceptions of corruption'] not found in axis"

# %%
world_happiness_report.head()
# Out:
#        country  happiness_score  gdp_per_capita  social_support    health  \
# 0      Finland           7.8087        1.285190        1.499526  0.961271
# 1      Denmark           7.6456        1.326949        1.503449  0.979333
# 2  Switzerland           7.5599        1.390774        1.472403  1.040533
# 3      Iceland           7.5045        1.326502        1.547567  1.000843
# 4       Norway           7.4880        1.424207        1.495173  1.008072
#
#     freedom  generosity  government_trust  dystopia_residual continent
# 0  0.662317    0.159670          0.477857           2.762835    Europe
# 1  0.665040    0.242793          0.495260           2.432741    Europe
# 2  0.628954    0.269056          0.407946           2.350267    Europe
# 3  0.661981    0.362330          0.144541           2.460688    Europe
# 4  0.670201    0.287985          0.434101           2.168266    Europe

# %%
columns_to_dropped = ['happiness_score','generosity','government_trust', 'dystopia_residual', 'continent']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-42149ea32b7b> in <module>
#       1 columns_to_dropped = ['happiness_score','generosity','government_trust', 'dystopia_residual', 'continent']
# ----> 2 world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['happiness_score' 'generosity' 'government_trust' 'dystopia_residual'\n 'continent'] not found in axis"

# %%
world_happiness_report.head()
# Out:
#        country  gdp_per_capita    health   freedom
# 0      Finland        1.285190  0.961271  0.662317
# 1      Denmark        1.326949  0.979333  0.665040
# 2  Switzerland        1.390774  1.040533  0.628954
# 3      Iceland        1.326502  1.000843  0.661981
# 4       Norway        1.424207  1.008072  0.670201

# %%
world_happiness_report.set_index(['country'],inplace=True)
world_happiness_report.head()
# Out:
#              gdp_per_capita    health   freedom
# country
# Finland            1.285190  0.961271  0.662317
# Denmark            1.326949  0.979333  0.665040
# Switzerland        1.390774  1.040533  0.628954
# Iceland            1.326502  1.000843  0.661981
# Norway             1.424207  1.008072  0.670201

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
world_happiness_report.head()
# Out:
#              gdp_per_capita    health   freedom
# country
# Finland            1.285190  0.961271  0.662317
# Denmark            1.326949  0.979333  0.665040
# Switzerland        1.390774  1.040533  0.628954
# Iceland            1.326502  1.000843  0.661981
# Norway             1.424207  1.008072  0.670201

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#              gdp_per_capita    health   freedom  max infection rate
# country
# Finland            1.285190  0.961271  0.662317               267.0
# Denmark            1.326949  0.979333  0.665040               391.0
# Switzerland        1.390774  1.040533  0.628954              1321.0
# Iceland            1.326502  1.000843  0.661981                99.0
# Norway             1.424207  1.008072  0.670201               386.0

# %%
data.corr()
# Out:
#                     gdp_per_capita    health   freedom  max infection rate
# gdp_per_capita            1.000000  0.850458  0.407600            0.236304
# health                    0.850458  1.000000  0.436211            0.275299
# freedom                   0.407600  0.436211  1.000000            0.071525
# max infection rate        0.236304  0.275299  0.071525            1.000000

# %%
data.head()
# Out:
#              gdp_per_capita    health   freedom  max infection rate
# country
# Finland            1.285190  0.961271  0.662317               267.0
# Denmark            1.326949  0.979333  0.665040               391.0
# Switzerland        1.390774  1.040533  0.628954              1321.0
# Iceland            1.326502  1.000843  0.661981                99.0
# Norway             1.424207  1.008072  0.670201               386.0

# %%
x = data['gdp_per_capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='max infection rate'>

# %%
x = data['health']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='health', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='health', ylabel='max infection rate'>

# %%
x = data['freedom']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='freedom', ylabel='max infection rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='freedom', ylabel='max infection rate'>
